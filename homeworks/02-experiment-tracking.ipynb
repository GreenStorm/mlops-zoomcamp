# %% [markdown]
# ### Q1. Install MLflow

# %%
# %%bash
# conda update conda
# conda create -n two-et -y mlflow
# source activate two-et
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /opt/conda/envs/02-et
#   package name: conda
# Channels:
#  - defaults
# Platform: linux-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/two-et
#
#   added / updated specs:
#     - mlflow
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   abseil-cpp         pkgs/main/linux-64::abseil-cpp-20211102.0-hd4dd3e8_0
#   alembic            pkgs/main/linux-64::alembic-1.8.1-py312h06a4308_0
#   aniso8601          pkgs/main/noarch::aniso8601-9.0.1-pyhd3eb1b0_0
#   arrow-cpp          pkgs/main/linux-64::arrow-cpp-14.0.2-h374c478_1
#   aws-c-auth         pkgs/main/linux-64::aws-c-auth-0.6.19-h5eee18b_0
#   aws-c-cal          pkgs/main/linux-64::aws-c-cal-0.5.20-hdbd6064_0
# ...

# %%
# !mlflow --version
# Out:
# mlflow, version 2.12.2

# %% [markdown]
# Select the conda env from the dropdown menu on the top right
